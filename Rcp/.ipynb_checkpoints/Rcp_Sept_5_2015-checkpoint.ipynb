# %%
# %run 'lib_rcp_plotter.ipynb'

# %%
plc = "Pi"
input_file = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root"
data = root_open( input_file )

can = Canvas( width=800, height=400 )
can.Divide(2, 1)

can.SetLeftMargin( 0.2 )

R.gStyle.SetOptStat( 0 )

can.cd(1)
charge = "p"

hRcp_14 = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=34, trim=12 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )



R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )

can.cd(2)
charge = "n"
plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=32, trim=12 )

R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )

R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )


can
# Out:
# Canvas('62d03b1d7d6f40cab1d4c13334904e6d')

# %%
plc = "K"
input_file = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root"
data = root_open( input_file )

can = Canvas( width=800, height=400 )
can.Divide(2, 1)

can.SetLeftMargin( 0.2 )
can.cd(1)
R.gStyle.SetOptStat( 0 )

charge = "p"

hRcp_14 = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=33, trim=12 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )



R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )
can.cd(2)
charge = "n"
plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=30, trim=12 )

R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )

R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )


can
# Out:
# Canvas('56d68cf326ec46eaaf7237ab9b041548')

# %%
plc = "P"
input_file = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root"
data = root_open( input_file )

can = Canvas( width=800, height=400 )
can.Divide(2, 1)
can.SetLeftMargin( 0.2 )

R.gStyle.SetOptStat( 0 )


charge = "p"
can.cd(1)
hRcp_14 = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=63, trim=12 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )



R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )


charge = "n"
can.cd(2)
plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=69, trim=12 )

R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )

R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )


can
# Out:
# Canvas('39659937918c4da3b7bd68aca4aa558d')

# %%
canl = Canvas( width=300, height=150 )
leg = R.TLegend( 0.0, 0.0, 1.0, 1.0 )
leg.AddEntry( hRcp_7, "7.7", "p" )
leg.AddEntry( hRcp_11, "11.5", "p" )
leg.AddEntry( hRcp_14, "14.5", "p" )
leg.AddEntry( hRcp_19, "19.6", "p" )
leg.AddEntry( hRcp_27, "27.0", "p" )
leg.AddEntry( hRcp_39, "39.0", "p" )
leg.SetNColumns(3);
leg.Draw()
R.gPad.Print( "sqrt_s_NN_legend.pdf" )
canl
# Out:
# Canvas('163bfbc9b28a46c2a18a3fe9c3b65f4f')

# %%
can = Canvas( width=300, height=450 )
R.gStyle.SetOptStat(0)

plc = "Pi"
charge = "p"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=34, trim=12 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

plc = "K"
charge = "p"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
K = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kGreen, trunc=33, draw="same", trim=12 )


plc = "P"
charge = "p"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
P = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kBlue, trunc=33, draw="same", trim=12 )


R.gPad.Print( "RCP_Positive.pdf" )

can
# Out:
# Canvas('594aa25b2d434b7282f65506922d5533')

# %%
can = Canvas( width=300, height=450 )
R.gStyle.SetOptStat(0)

plc = "Pi"
charge = "n"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=31, trim=12 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

plc = "K"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kGreen, trunc=30, draw="same", trim=12 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

plc = "P"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kBlue, trunc=31, draw="same", trim=12 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

R.gPad.Print( "RCP_Negative.pdf" )

can
# Out:
# Canvas('5e70d6b3aba84367867ebd9f7976b470')
