# %%
# %run 'fitlib.ipynb'

# %%
fName = "/Users/danielbrandenburg/bnl/local/data/RcpAnalysis/products/nominal_01/Fit_PostCorr_Pi.root"
f = root_open( fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "5", "p", True )
# Out:
# Canvas('189c3463d8cc4576813747298831bcf9')
