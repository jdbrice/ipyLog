# %%
# %run 'fitlib.ipynb'

# %%
fName = "Fit_Corr_Pi.root"
path = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/"
f = root_open( path+fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "6", "n", True )
# Out:
# Canvas('54a06a8e471c48a5a95ad15550f5ac6f')
