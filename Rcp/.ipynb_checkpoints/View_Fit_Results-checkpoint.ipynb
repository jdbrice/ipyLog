# %%
# %run 'fitlib.ipynb'

# %%
fName = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Fit_PostCorr_K.root"
f = root_open( fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "n", True )
# Out:
# Canvas('8e32d1a782c24b1c880a30d0cf06c6be')
