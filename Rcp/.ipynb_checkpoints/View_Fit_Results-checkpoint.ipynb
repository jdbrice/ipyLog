# %%
# %run 'fitlib.ipynb'

# %%
fName = "pid_table.root"
path = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/bin/"
f = root_open( path+fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "6", "p" )
# Out:
# Canvas('a5c7bc96abca43268a217f8485baab44')

# %%
fName = "all_fit.root"
path = "/Users/danielbrandenburg/Desktop/present/"
f = root_open( path+fName )

# %%
drawAll( "6", "n" )
# Out:
# Canvas('03d59cc23fe54e898aecbc55a7e7d8ea')

# %%
fName = "all_fit.root"
path = "/Users/danielbrandenburg/Desktop/present/"
f1 = root_open( path+fName )

fName = "pid_table.root"
path = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/bin/"
f2 = root_open( path+fName )

# %%
can = Canvas( width=800, height=800 )
f1.K_yield.yield_K_0_n_0.Draw()
#f1.K_yield.yield_K_0_n_0.GetYaxis().SetRangeUser( 1e5, 1e7/2 )
f1.K_yield.yield_K_0_n_0.GetXaxis().SetRangeUser( 1.5, 2 )
f2.K_yield.yield_K_0_n_0.SetMarkerColor( 2 )
f2.K_yield.yield_K_0_n_0.Draw("same")
R.gPad.SetLogy(0)
can
# Out:
# Canvas('543a7aa092fe483da53f9d5c4b6bbf9e')
