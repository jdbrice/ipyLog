# %%
# %run 'fitlib.ipynb'

# %%
fName = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/Fit_tof_Pi.root"
f = root_open( fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "n", True )
# Out:
# Canvas('cc2caef744d94aef9fe36479f3800b03')

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "p", True )
# Out:
# Canvas('c2f434d0d70b4788a33b100d9f009c56')

# %%
R.gStyle.SetOptStat(0)
drawAll( "6", "p", True )
# Out:
# Canvas('2a57bc564d814cc08afc3aed69d37095')

# %%
R.gStyle.SetOptStat(0)
drawAll( "6", "n", True )
# Out:
# Canvas('7d6b7bbc369543cabf9748459d7402bf')
