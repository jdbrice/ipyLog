# %%
# %run 'lib_rcp_plotter.ipynb'

# %%
plc = "K"
input_file = "/Users/danielbrandenburg/bnl/local/data/RcpAnalysis/products/nominal/Present_PostCorr_" + plc + ".root"
data = root_open( input_file )

can = Canvas( width=500, height=500 )
can.SetLeftMargin( 0.2 )

R.gStyle.SetOptStat( 0 )




charge = "p"

plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=21 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)


hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

R.gPad.Print( "rcp_" + plc + "_" + charge + ".pdf" )


charge = "n"
plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=21 )

R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")
R.gPad.Print( "rcp_" + plc + "_" + charge + ".pdf" )

can
# Out:
# Canvas('62c2c720bb86432586a8e69fcd854f3b')

# %%
data.close()
# Out:
# False
