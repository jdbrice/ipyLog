# %%
# %run 'lib_rcp_plotter.ipynb'

# %%
plc = "K"
input_file = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root"
data = root_open( input_file )

can = Canvas( width=800, height=300 )
can.SetLeftMargin( 0.2 )

R.gStyle.SetOptStat( 0 )


charge = "p"

hRcp_14 = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=62 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )



R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )


charge = "n"
plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=61 )

R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_7 = get_evan_rcp( "7.7", plc, charge, 0, 6, color=R.kMagenta)
hRcp_7.Draw("same")

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_27 = get_evan_rcp( "27.0", plc, charge, 0, 6, color=R.kOrange)
hRcp_27.Draw( "same" )

hRcp_39 = get_evan_rcp( "39.0", plc, charge, 0, 6, color=R.kOrange-6)
hRcp_39.Draw( "same" )

R.gPad.Print( "rcp_PostCorr_" + plc + "_" + charge +".pdf" )


can
# Out:
# Canvas('af0365c7e2c94cdfba39b2d5bcb9f321')

# %%
data.close()
# Out:
# False

# %%
canl = Canvas( width=300, height=150 )
leg = R.TLegend( 0.0, 0.0, 1.0, 1.0 )
leg.AddEntry( hRcp_7, "7.7", "p" )
leg.AddEntry( hRcp_11, "11.5", "p" )
leg.AddEntry( hRcp_14, "14.5", "p" )
leg.AddEntry( hRcp_19, "19.6", "p" )
leg.AddEntry( hRcp_27, "27.0", "p" )
leg.AddEntry( hRcp_39, "39.0", "p" )
leg.SetNColumns(3);
leg.Draw()
R.gPad.Print( "sqrt_s_NN_legend.pdf" )
canl
# Out:
# Canvas('163bfbc9b28a46c2a18a3fe9c3b65f4f')

# %%
can = Canvas( width=400, height=400 )
R.gStyle.SetOptStat(0)

plc = "Pi"
charge = "p"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=62 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

plc = "K"
charge = "p"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kGreen, trunc=62, draw="same" )


plc = "P"
charge = "p"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kBlue, trunc=62, draw="same" )


R.gPad.Print( "RCP_Positive.pdf" )

can
# Out:
# Canvas('fb80ae1515aa4c80901202b31f09ff28')

# %%
can = Canvas( width=400, height=400 )
R.gStyle.SetOptStat(0)

plc = "Pi"
charge = "n"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed, trunc=62 )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

plc = "K"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kGreen, trunc=62, draw="same" )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

plc = "P"
data = root_open( "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Present_PostCorr_" + plc + ".pdf.root" )
pi = plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kBlue, trunc=62, draw="same" )
R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

R.gPad.Print( "RCP_Negative.pdf" )

can
# Out:
# Canvas('31692f327f094618be9b256de5132a00')
