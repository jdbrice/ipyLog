# %%
# %run 'fitlib.ipynb'

# %%
fName = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/Fit_tof_Pi.root"
f = root_open( fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "n", True )
# Out:
# Canvas('267b789e2b9648f5b60d643489aeaf84')
