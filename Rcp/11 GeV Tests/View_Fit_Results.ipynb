# %%
# %run '../fitlib.ipynb'

# %%
fName = "tsf_15_test.root"
path = "/Users/danielbrandenburg/bnl/local/work/saveMe/bin/"
f = root_open( path+fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "n" )
# Out:
# Canvas('e78bd73b5f974bc3a6297d47a035e078')
