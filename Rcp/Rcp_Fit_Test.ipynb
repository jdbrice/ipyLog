# %%
# %run 'lib_rcp_plotter.ipynb'

# %%
input_file = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/Present_K.root"
data = root_open( input_file )

# %%
can = Canvas( width=500, height=500 )

R.gStyle.SetOptStat( 0 )

plc = "K"
charge = "n"

plot_dans_rcp( plc=plc, charge=charge, iCen=0, iPer=6, color = R.kRed )

R.gPad.SetLogy(1)
R.gPad.SetGrid(1, 1)

hRcp_19 = get_evan_rcp( "19.6", plc, charge, 0, 6, color=R.kBlue)
hRcp_19.Draw( "same" )

hRcp_11 = get_evan_rcp( "11.5", plc, charge, 0, 6, color=R.kGreen)
hRcp_11.Draw("same")

can
# Out:
# Canvas('b1d41ba073814523be9dd1a6a7b1ff5d')
