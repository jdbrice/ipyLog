# %%
# %run 'fitlib.ipynb'

# %%
fName = "/Users/danielbrandenburg/bnl/local/data/RcpAnalysis/products/nominal/Fit_PostCorr_Pi.root"
f = root_open( fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "p", True )
# Out:
# Canvas('4a09604671e746308245c71c710f2372')
