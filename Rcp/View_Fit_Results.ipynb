# %%
# %run 'fitlib.ipynb'

# %%
fName = "tsf_15_pt_eta.root"
path = "/Users/danielbrandenburg/Desktop/present/"
f = root_open( path+fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "n" )
# Out:
# Canvas('579293ac072b49d391ed1834baedbf40')

# %%
scan = Canvas( width=400, height=400 )
saveZbMu( "0", "n", scan)
