# %%
# %run 'fitlib.ipynb'

# %%
fName = "pid_table.root"
path = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/bin/"
f = root_open( path+fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "6", "n" )
# Out:
# Canvas('ae355d961bea40758401864f956ba7ac')

# %%
scan = Canvas( width=400, height=400 )
saveZbMu( "0", "n", scan)
