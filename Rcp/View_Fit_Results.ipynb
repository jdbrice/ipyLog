# %%
# %run 'fitlib.ipynb'

# %%
fName = "pid_table_all_mb.root"
path = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/bin/"
f = root_open( path+fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "6", "n" )
# Out:
# Canvas('2f951811de09402b86968e88133587e1')
