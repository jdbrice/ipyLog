# %%
# %run 'fitlib.ipynb'

# %%
fName = "/Users/danielbrandenburg/bnl/local/work/rcpMaker/products/nominal/Fit_PostCorr_P.root"
f = root_open( fName )

# %%
R.gStyle.SetOptStat(0)
drawAll( "0", "p", True )
# Out:
# Canvas('2299d3048a2c4084ab8d4ee0b787049a')
