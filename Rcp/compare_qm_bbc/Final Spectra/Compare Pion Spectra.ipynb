# %%
import ROOT
# ROOT.enableJSVis()
# Out:
# Welcome to ROOTaaS 6.06/02

# %%
f1 = ROOT.TFile( "qm_nominal/PostCorr_Pi.root" )
f2 = ROOT.TFile( "BBC_MB_PostCorr_Pi.root")

# %%
def compare( plc, ch, cen ) :
    name = plc + "_yield/yield_" + plc + "_" + cen + "_" + ch
    
    h1 = f1.Get( name )
    h2 = f2.Get( name )
    
    cc = ROOT.TCanvas( "ccan_" + name, "ccan", 1000, 500 )
    
    h1.Draw()
    h2.SetLineColor( ROOT.kRed )
    h1.Draw()
    h2.Draw("same")
    cc.SetLogy(1)
    cc.Draw()
    
    cc2 = ROOT.TCanvas( "cc2an_" + name, "ccan", 1000, 500 )
    hr = h1.Clone( "ratio_" + name )
    hr.Divide( h2 )
    hr.Draw()
    hr.SetMarkerStyle( 8 )
    hr.Fit( "pol0", "R", "", 0.5, 2.5 )
    hr.GetYaxis().SetRangeUser( 0.9, 1.1 )
    cc2.Draw()

# %% [markdown]
# ## Comparing Spectra
# 1) QM Spectra used track-by-track corrections
# 2) BBC_MB spectra is using bin-center corrections (So expect about a 2% systematic shift )
# - The (significantly) reduced statistics in BBC_MB only affects the spectra starting at about pT = 1.5 GeV

# %%
compare( "Pi", "p", "0" )
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: ccan_Pi_yield/yield_Pi_0_p
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: cc2an_Pi_yield/yield_Pi_0_p
# ****************************************
# Minimizer is Linear
# Chi2                      =      3706.31
# NDf                       =           17
# p0                        =     0.981382   +/-   8.07121e-05

# %%
compare( "Pi", "p", "1")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      3344.08
# NDf                       =           17
# p0                        =     0.985634   +/-   8.96162e-05

# %%
compare( "Pi", "p", "2")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =       7880.7
# NDf                       =           17
# p0                        =     0.986886   +/-   6.98407e-05

# %%
compare( "Pi", "p", "3" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      6621.06
# NDf                       =           17
# p0                        =     0.991065   +/-   8.35918e-05

# %%
compare( "Pi", "p", "4" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      1692.39
# NDf                       =           17
# p0                        =     0.990811   +/-   0.00010264

# %%
compare( "Pi", "p", "5" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      7513.81
# NDf                       =           17
# p0                        =     0.992281   +/-   0.000106996

# %%
compare( "Pi", "p", "6" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      2116.84
# NDf                       =           17
# p0                        =      1.00878   +/-   0.00020334

# %%
compare( "Pi", "n", "0")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      1788.75
# NDf                       =           17
# p0                        =     0.982004   +/-   7.96281e-05

# %%
compare( "Pi", "n", "1")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      1671.14
# NDf                       =           17
# p0                        =     0.984964   +/-   8.8028e-05

# %%
compare( "Pi", "n", "2")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      4480.69
# NDf                       =           17
# p0                        =     0.987779   +/-   6.84074e-05

# %%
compare( "Pi", "n", "3")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      6647.84
# NDf                       =           17
# p0                        =     0.987271   +/-   8.22195e-05

# %%
compare( "Pi", "n", "4")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      4374.19
# NDf                       =           17
# p0                        =     0.992391   +/-   0.000101273

# %%
compare( "Pi", "n", "5")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      4822.25
# NDf                       =           17
# p0                        =     0.992878   +/-   0.00010488

# %%
compare( "Pi", "n", "6")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      2375.62
# NDf                       =           17
# p0                        =     0.997663   +/-   0.000193896
