# %%
import ROOT
# ROOT.enableJSVis()
# Out:
# Welcome to ROOTaaS 6.06/02

# %%
f1 = ROOT.TFile( "PostCorr_P.root" )
f2 = ROOT.TFile( "BBC_MB_PostCorr_P.root")

# %%
def compare( plc, ch, cen ) :
    name = plc + "_yield/yield_" + plc + "_" + cen + "_" + ch
    
    h1 = f1.Get( name )
    h2 = f2.Get( name )
    
    cc = ROOT.TCanvas( "ccan_" + name, "ccan", 600, 800 )
    
    h1.Draw()
    h2.SetLineColor( ROOT.kRed )
    h1.Draw()
    h2.Draw("same")
    cc.SetLogy(1)
    cc.Draw()
    
    cc2 = ROOT.TCanvas( "cc2an_" + name, "ccan", 1000, 800 )
    hr = h1.Clone( "ratio_" + name )
    hr.Divide( h2 )
    hr.Draw()
    hr.Fit( "pol0", "WR", "", 0.5, 2.5 )
    hr.GetYaxis().SetRangeUser( 0.9, 1.1 )
    cc2.Draw()

# %% [markdown]
# ## Comparing Spectra
# 1) QM Spectra used track-by-track corrections
# 2) BBC_MB spectra is using bin-center corrections

# %%
compare( "P", "p", "0" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0171522
# NDf                       =           17
# p0                        =      1.00705   +/-   0.235702

# %%
compare( "P", "p", "1")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0201725
# NDf                       =           17
# p0                        =      1.01096   +/-   0.235702

# %%
compare( "P", "p", "2")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0147244
# NDf                       =           17
# p0                        =      1.01091   +/-   0.235702

# %%
compare( "P", "p", "3" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0134966
# NDf                       =           17
# p0                        =      1.01153   +/-   0.235702

# %%
compare( "P", "p", "4" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0150836
# NDf                       =           17
# p0                        =      1.02024   +/-   0.235702

# %%
compare( "P", "p", "5" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0141052
# NDf                       =           17
# p0                        =      1.02607   +/-   0.235702

# %%
compare( "P", "p", "6" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0164223
# NDf                       =           17
# p0                        =      1.03851   +/-   0.235702

# %%
compare( "P", "n", "0")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0347729
# NDf                       =           17
# p0                        =      1.00205   +/-   0.235702

# %%
compare( "P", "n", "1")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0438118
# NDf                       =           17
# p0                        =     0.998377   +/-   0.235702

# %%
compare( "P", "n", "2")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0344727
# NDf                       =           17
# p0                        =     0.995155   +/-   0.235702

# %%
compare( "P", "n", "3")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0399864
# NDf                       =           17
# p0                        =     0.994105   +/-   0.235702

# %%
compare( "P", "n", "4")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0497735
# NDf                       =           17
# p0                        =       1.0118   +/-   0.235702

# %%
compare( "P", "n", "5")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0300369
# NDf                       =           17
# p0                        =      1.00545   +/-   0.235702

# %%
compare( "P", "n", "6")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0575922
# NDf                       =           17
# p0                        =      1.00591   +/-   0.235702
