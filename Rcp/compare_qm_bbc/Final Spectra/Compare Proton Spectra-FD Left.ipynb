# %%
import ROOT
# ROOT.enableJSVis()
# Out:
# Welcome to ROOTaaS 6.06/02

# %%
f1 = ROOT.TFile( "PostCorr_P.root" )
f2 = ROOT.TFile( "BBC_MB_PostCorr_P.root")

# %%
def compare( plc, ch, cen ) :
    name = plc + "_yield/yield_" + plc + "_" + cen + "_" + ch
    
    h1 = f1.Get( name )
    h2 = f2.Get( name )
    
    cc = ROOT.TCanvas( "ccan_" + name, "ccan", 600, 800 )
    
    h1.Draw()
    h2.SetLineColor( ROOT.kRed )
    h1.Draw()
    h2.Draw("same")
    cc.SetLogy(1)
    cc.Draw()
    
    cc2 = ROOT.TCanvas( "cc2an_" + name, "ccan", 1000, 800 )
    hr = h1.Clone( "ratio_" + name )
    hr.Divide( h2 )
    hr.Draw()
    hr.Fit( "pol0", "WR", "", 0.5, 2.5 )
    hr.GetYaxis().SetRangeUser( 0.9, 1.1 )
    cc2.Draw()

# %% [markdown]
# ## Comparing Spectra
# 1) QM Spectra used track-by-track corrections
# 2) BBC_MB spectra is using bin-center corrections

# %%
compare( "P", "p", "0" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0232107
# NDf                       =           17
# p0                        =      1.00722   +/-   0.235702

# %%
compare( "P", "p", "1")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0256846
# NDf                       =           17
# p0                        =      1.01122   +/-   0.235702

# %%
compare( "P", "p", "2")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0209036
# NDf                       =           17
# p0                        =       1.0114   +/-   0.235702

# %%
compare( "P", "p", "3" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0185033
# NDf                       =           17
# p0                        =       1.0113   +/-   0.235702

# %%
compare( "P", "p", "4" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0202148
# NDf                       =           17
# p0                        =      1.01974   +/-   0.235702

# %%
compare( "P", "p", "5" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0196997
# NDf                       =           17
# p0                        =      1.02606   +/-   0.235702

# %%
compare( "P", "p", "6" )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =     0.022927
# NDf                       =           17
# p0                        =      1.03998   +/-   0.235702

# %%
compare( "P", "n", "0")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =    0.0466746
# NDf                       =           17
# p0                        =     0.995509   +/-   0.235702

# %%
compare( "P", "n", "1")
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =     0.056599
# NDf                       =           17
# p0                        =     0.993223   +/-   0.235702

# %%
compare( "P", "n", "2")

# %%
compare( "P", "n", "3")

# %%
compare( "P", "n", "4")

# %%
compare( "P", "n", "5")

# %%
compare( "P", "n", "6")
