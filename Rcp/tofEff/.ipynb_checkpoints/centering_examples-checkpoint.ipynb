# %%
# %run 'genlib.ipynb'

import rootpy.ROOT as R
R.gROOT.SetBatch(True)
from rootpy.io import root_open, DoesNotExist
import numpy as np
from rootpy.plotting import Canvas, Hist, Legend
# Out:
# 0.00280428627167
# 1.11521617048

# %%
c = R.TChain( "rcpPicoDst" )
c.Add( "~/bnl/local/data/RcpAnalysis/data/RcpPicoDst/*.root" )
# Out:
# 104

# %%
can = Canvas( width=800, height=800 )
#c.Draw( "dedx / 2000.0 :pP>>h2( 100, 0, 4, 350, 0, 3.5 )", "", "colz" )
#R.gPad.SetLogz(1)
#can

# %%
h2 = R.TH2F( "h", "h", 100, 0, 4, 500, 1, 8 )
# Out:
# WARNING:ROOT.TFile.Append:Replacing existing TH1: h (Potential memory leak).

# %%
b = Bischel(  )
b.mean( "K", 1.0 ) * 1000
# Out:
# 2.804286271674385

# %%
for event in range( 0, 10 ) :
    c.GetEntry( event )
    
    for iTrack in range( 0, c.nTracks ) :
        p = c.pP[ iTrack ]
        dedx = c.dedx[ iTrack ] / 1000.0
        h2.Fill( p, dedx - b.mean( "K", p )*1000 )
        print
# Out:
# 2.66388101149
# 2.70990972817
# 7.97846166169
# 6.40249593287
# 3.86268474822
# 2.96224840033
# 5.11160159687
# 3.75410556604
# 4.95147456863
# 4.79995728759
# 2.65497311534
# 5.45475528693
# 2.88809126964
# 2.77767508496
# 2.94762149919
# 6.66464446932
# 3.13744101708
# 2.94762149919
# 3.25412966788
# 4.49549441791
# 4.41960502591
# 6.94609920156
# 8.38949562453
# 14.3463169109
# 4.20324748835
# 2.67076127321
# 2.90905376315
# 10.6487504297
# 2.96224840033
# 4.79995728759
# 12.2918438701
# 4.49549441791
# 3.47984128922
# 3.37767821413
# 3.31370337603
# 2.97712228258
# 4.65650776316
# 6.40249593287
# 8.86163900683
# 3.02329918621
# 5.45475528693
# 3.07298163958
# 3.28286077798
# 4.27618076029
# 9.38779745898
# 3.70375013866
# 5.28105597473
# 4.95147456863
# 2.91977061285
# 12.2918438701
# 2.62229023799
# 6.1598040775
# 2.67309432176
# 5.45475528693
# 8.38949562453
# 3.28286077798
# 7.25197577424
# 3.8060552483
# 3.00764003305
# 2.63965868751
# 2.67782184106
# 5.28105597473
# ...

# %%
h2.Draw( "colz" )
can
# Out:
# Canvas('77594529fffb475e9db260af20d86781')
