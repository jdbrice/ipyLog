# %%
# %matplotlib inline
import rootpy.ROOT as R
R.gROOT.SetBatch(True)
import numpy as np
from rootpy.io import root_open, DoesNotExist
from rootpy.plotting import Canvas, Hist, Legend

# %%
mc = R.TChain( "StMiniMcTree" )
path = "/Users/danielbrandenburg/bnl/local/data/BES/15GeV/urqmd/wrong_vtx/*.root"
mc.Add( path )
# Out:
# 2580

# %%
can = Canvas( width=900, height=600)

# %% [markdown]
# ## Energy Loss : $\pi^+$

# %%
hstr = ">>hPi_p_EnergyLoss(100, 0.1, 2.1, 50, -0.1, 0.1)"
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr - StMiniMcEvent.mMatchedPairs.mPtMc : StMiniMcEvent.mMatchedPairs.mPtPr" + hstr, "StMiniMcEvent.mMatchedPairs.mGeantId==8 && StMiniMcEvent.mMatchedPairs.mParentGeantId==0", "colz")
# Out:
# 25141L

# %%
R.hPi_p_EnergyLoss.Draw("colz")
R.gPad.SetLogy(0)
R.gPad.SetLogz(1)
can
# Out:
# Canvas('e44ce76d6260440fbfba5b9a6dc54f80')

# %% [markdown]
# ## Energy Loss : $\pi^-$

# %%
hstr = ">>hPi_m_EnergyLoss(100, 0.1, 2.1, 50, -0.1, 0.1)"
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr - StMiniMcEvent.mMatchedPairs.mPtMc : StMiniMcEvent.mMatchedPairs.mPtPr" + hstr, "StMiniMcEvent.mMatchedPairs.mGeantId==9 && StMiniMcEvent.mMatchedPairs.mParentGeantId==0", "colz")
R.gPad.SetLogy(0)
can
# Out:
# Canvas('e44ce76d6260440fbfba5b9a6dc54f80')

# %% [markdown]
# ## Energy Loss : K$^+$

# %%
hstr = ">>hK_p_EnergyLoss(100, 0.1, 2.1, 50, -0.1, 0.1)"
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr - StMiniMcEvent.mMatchedPairs.mPtMc : StMiniMcEvent.mMatchedPairs.mPtPr" + hstr, "StMiniMcEvent.mMatchedPairs.mGeantId==11 && StMiniMcEvent.mMatchedPairs.mParentGeantId==0", "colz")
R.gPad.SetLogy(0)
can
# Out:
# Canvas('e44ce76d6260440fbfba5b9a6dc54f80')

# %% [markdown]
# ## K$^-$

# %%
hstr = ">>hK_m_EnergyLoss(100, 0.1, 2.1, 50, -0.1, 0.1)"
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr - StMiniMcEvent.mMatchedPairs.mPtMc : StMiniMcEvent.mMatchedPairs.mPtPr" + hstr, "StMiniMcEvent.mMatchedPairs.mGeantId==12 && StMiniMcEvent.mMatchedPairs.mParentGeantId==0", "colz")
# Out:
# 1244L

# %%
R.hK_m_EnergyLoss.Draw("colz")
can
# Out:
# Canvas('e44ce76d6260440fbfba5b9a6dc54f80')

# %%
hstr = ">>hP_p_EnergyLoss(100, 0.1, 2.1, 50, -0.1, 0.1)"
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr - StMiniMcEvent.mMatchedPairs.mPtMc : StMiniMcEvent.mMatchedPairs.mPtPr" + hstr, "StMiniMcEvent.mMatchedPairs.mGeantId==14 && StMiniMcEvent.mMatchedPairs.mParentGeantId==0", "colz")
R.gPad.SetLogy(0)
can
# Out:
# Canvas('e44ce76d6260440fbfba5b9a6dc54f80')

# %%
hstr = ">>hP_m_EnergyLoss(100, 0.1, 2.1, 50, -0.1, 0.1)"
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr - StMiniMcEvent.mMatchedPairs.mPtMc : StMiniMcEvent.mMatchedPairs.mPtPr" + hstr, "StMiniMcEvent.mMatchedPairs.mGeantId==15 && StMiniMcEvent.mMatchedPairs.mParentGeantId==0", "colz")
R.gPad.SetLogy(0)
can
# Out:
# Canvas('e44ce76d6260440fbfba5b9a6dc54f80')

# %%
mc.Draw( "StMiniMcEvent.mMatchedPairs.mGeantId>>hMatchedPID", "StMiniMcEvent.mMatchedPairs.mPtMc > 0.1", "h" )
mc.Draw( "StMiniMcEvent.mMcTracks.mGeantId>>hMcPID", "StMiniMcEvent.mMcTracks.mPtMc > 0.1", "h" )
R.hMcPID.SetLineColor( R.kRed )
R.hMcPID.SetLineWidth( 2 )
R.hMcPID.SetTitle("MC (Red), Matched (Black)" )
R.hMatchedPID.Draw("same h")
R.gPad.SetLogy(1)
can
# Out:
# Canvas('e44ce76d6260440fbfba5b9a6dc54f80')

# %%
mc.Draw( "StMiniMcEvent.mMatchedPairs.mParentGeantId", "StMiniMcEvent.mMatchedPairs.mGeantId == 14 && StMiniMcEvent.mNumUncorrectedPrimaries > 5", "h" )
can

# %%
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr>>hBackPi", "StMiniMcEvent.mMatchedPairs.mParentGeantId>0 && StMiniMcEvent.mMatchedPairs.mGeantId==8 && StMiniMcEvent.mMatchedPairs.mPtPr > 0.1  && StMiniMcEvent.mMatchedPairs.mDedxPts > 10 && StMiniMcEvent.mMatchedPairs.mFitPts > 15 && StMiniMcEvent.mMatchedPairs.mFitPts / StMiniMcEvent.mMatchedPairs.mAllPts > 0.52 && StMiniMcEvent.mMatchedPairs.mDcaGl < 1.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr < 10.0 / 7.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr > 7.0 / 10.0 && StMiniMcEvent.mNUncorrectedPrimaries > 5 && sqrt( StMiniMcEvent.mVertexX*StMiniMcEvent.mVertexX + (StMiniMcEvent.mVertexY + 0.89)*(StMiniMcEvent.mVertexY + 0.89) ) < 1.0 ")
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr>>hSigPi", "StMiniMcEvent.mMatchedPairs.mParentGeantId==0 && StMiniMcEvent.mMatchedPairs.mGeantId==8 && StMiniMcEvent.mMatchedPairs.mPtPr > 0.1  && StMiniMcEvent.mMatchedPairs.mDedxPts > 10 && StMiniMcEvent.mMatchedPairs.mFitPts > 15 && StMiniMcEvent.mMatchedPairs.mFitPts / StMiniMcEvent.mMatchedPairs.mAllPts > 0.52 && StMiniMcEvent.mMatchedPairs.mDcaGl < 1.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr < 10.0 / 7.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr > 7.0 / 10.0 && StMiniMcEvent.mNUncorrectedPrimaries > 5 && sqrt( StMiniMcEvent.mVertexX*StMiniMcEvent.mVertexX + (StMiniMcEvent.mVertexY + 0.89)*(StMiniMcEvent.mVertexY + 0.89) ) < 1.0 ")
can
# Out:
# Canvas('83b19fc409bf400d9ec9bc1a567852a6')

# %%
R.hBackPi.Draw()
R.hSigPi.Draw()
hFracPi = R.hBackPi.Clone( "hFracPi" )
hFracPi.Divide( R.hSigPi )
hFracPi.Draw()
R.gPad.SetLogy(1)
can
# Out:
# Canvas('83b19fc409bf400d9ec9bc1a567852a6')

# %%
can.SetFillColorAlpha( 0, 0 )

# %%
can
# Out:
# Canvas('83b19fc409bf400d9ec9bc1a567852a6')

# %%
can.Print( "test.eps" )
