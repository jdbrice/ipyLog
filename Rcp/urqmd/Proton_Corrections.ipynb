# %%
# %matplotlib inline
import rootpy.ROOT as R
R.gROOT.SetBatch(True)
import numpy as np
from rootpy.io import root_open, DoesNotExist
from rootpy.plotting import Canvas, Hist, Legend

# %%
def labelsForGEANT( hist ) :
    x = hist.GetXaxis()
    x.SetBinLabel( 1, "No ID" )
    x.SetBinLabel( 2, "#gamma")
    x.SetBinLabel( 3, "e^{+}" )
    x.SetBinLabel( 4, "e^{-}" )
    x.SetBinLabel( 5, "#nu" )
    x.SetBinLabel( 6, "#mu^{+}" )
    x.SetBinLabel( 7, "#mu^{-}" )
    x.SetBinLabel( 8, "#pi" )
    x.SetBinLabel( 9, "#pi^{+}" )
    x.SetBinLabel( 10, "#pi^{-}" )
    x.SetBinLabel( 11, "K^{0}_{L}" )
    x.SetBinLabel( 12, "K^{+}" )
    x.SetBinLabel( 13, "K^{-}" )
    x.SetBinLabel( 14, "n" )
    x.SetBinLabel( 15, "P" )
    x.SetBinLabel( 16, "#bar{P}" )
    x.SetBinLabel( 17, "K^{0}_{S}" )
    x.SetBinLabel( 18, "#eta" )
    x.SetBinLabel( 19, "#Lambda" )
    x.SetBinLabel( 20, "#Sigma^{+}" )
    x.SetBinLabel( 21, "#Sigma^{0}" )
    x.SetBinLabel( 22, "#Sigma^{-}" )
    x.SetBinLabel( 23, "#Xi^{0}" )
    x.SetBinLabel( 24, "#Xi^{-}" )
    x.SetBinLabel( 25, "#Omega^{-}" )
    x.SetBinLabel( 26, "#bar{n}" )
    x.SetBinLabel( 27, "#bar{#Lambda}" )
    x.SetBinLabel( 28, "#bar{#Sigma^{-}}" )
    x.SetBinLabel( 29, "#bar{#Sigma^{0}}" )
    x.SetBinLabel( 30, "#bar{#Sigma^{+}}" )
    x.SetBinLabel( 31, "#bar{#Xi^{0}}" )
    x.SetBinLabel( 32, "#bar{#Xi^{+}}" )
    x.SetBinLabel( 33, "#bar{#Omega^{+}}" )

# %% [markdown]
# ## Proton Background

# %%
mc = R.TChain( "StMiniMcTree" )
path = "/Users/danielbrandenburg/bnl/local/data/BES/15GeV/urqmd/preview/*.root"
mc.Add( path )
# Out:
# 1561

# %%
can2 = Canvas( width=1200, height=600)
#can.SetBottomMargin( 0.01 )

# %%
mc.Draw( "StMiniMcEvent.mMatchedPairs.mParentGeantId>>hComp_dca( 34, -0.5, 33.5)", "StMiniMcEvent.mMatchedPairs.mGeantId==14 && StMiniMcEvent.mMatchedPairs.mPtPr > 0.4 && StMiniMcEvent.mMatchedPairs.mPtMc < 0.5 && StMiniMcEvent.mMatchedPairs.mDedxPts > 10 && StMiniMcEvent.mMatchedPairs.mFitPts > 15 && StMiniMcEvent.mMatchedPairs.mFitPts / StMiniMcEvent.mMatchedPairs.mAllPts > 0.52 && StMiniMcEvent.mMatchedPairs.mDcaGl < 0.5 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr < 10.0 / 7.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr > 7.0 / 10.0 && StMiniMcEvent.mNUncorrectedPrimaries > 5  " )
# Out:
# 6753L

# %%
labelsForGEANT( R.hComp )
R.hComp.Draw( "h")
R.hComp.SetTitle( "#Proton Parents")
R.gPad.SetLogy(1)
can2
# Out:
# Canvas('a5e4d3484f064c85b29b98271f9e50c0')

# %%
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr>>hBackPi(20, 0.1, 2.1)", "StMiniMcEvent.mMatchedPairs.mParentGeantId>0 && StMiniMcEvent.mMatchedPairs.mGeantId==14 && StMiniMcEvent.mMatchedPairs.mPtPr > 0.1  && StMiniMcEvent.mMatchedPairs.mDedxPts > 10 && StMiniMcEvent.mMatchedPairs.mFitPts > 15 && StMiniMcEvent.mMatchedPairs.mFitPts / StMiniMcEvent.mMatchedPairs.mAllPts > 0.52 && StMiniMcEvent.mMatchedPairs.mDcaGl < 1.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr < 10.0 / 7.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr > 7.0 / 10.0 && StMiniMcEvent.mNUncorrectedPrimaries > 5 && sqrt( StMiniMcEvent.mVertexX*StMiniMcEvent.mVertexX + (StMiniMcEvent.mVertexY + 0.89)*(StMiniMcEvent.mVertexY + 0.89) ) < 1.0 ")
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr>>hSigPi(20, 0.1, 2.1)", "StMiniMcEvent.mMatchedPairs.mParentGeantId==0 && StMiniMcEvent.mMatchedPairs.mGeantId==14 && StMiniMcEvent.mMatchedPairs.mPtPr > 0.1  && StMiniMcEvent.mMatchedPairs.mDedxPts > 10 && StMiniMcEvent.mMatchedPairs.mFitPts > 15 && StMiniMcEvent.mMatchedPairs.mFitPts / StMiniMcEvent.mMatchedPairs.mAllPts > 0.52 && StMiniMcEvent.mMatchedPairs.mDcaGl < 1.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr < 10.0 / 7.0 && StMiniMcEvent.mMatchedPairs.mPtGl/StMiniMcEvent.mMatchedPairs.mPtPr > 7.0 / 10.0 && StMiniMcEvent.mNUncorrectedPrimaries > 5 && sqrt( StMiniMcEvent.mVertexX*StMiniMcEvent.mVertexX + (StMiniMcEvent.mVertexY + 0.89)*(StMiniMcEvent.mVertexY + 0.89) ) < 1.0 ")
can2
# Out:
# Canvas('a5e4d3484f064c85b29b98271f9e50c0')

# %%
hFracPi = R.hBackPi.Clone( "hFracPi" )
hFracPi.Divide( R.hSigPi )
hFracPi.Draw()
R.gPad.SetLogy(1)
can2
# Out:
# Canvas('a5e4d3484f064c85b29b98271f9e50c0')

# %%
hstr = ">>hPi_p_EnergyLoss(100, 0.1, 2.1, 100, -0.1, 0.1)"
mc.Draw( "StMiniMcEvent.mMatchedPairs.mPtPr - StMiniMcEvent.mMatchedPairs.mPtMc : StMiniMcEvent.mMatchedPairs.mPtPr" + hstr, "StMiniMcEvent.mMatchedPairs.mGeantId==14 && StMiniMcEvent.mMatchedPairs.mParentGeantId==0", "colz")
# Out:
# 626651L

# %%
R.hPi_p_EnergyLoss.Draw("colz")
R.gPad.SetLogy(0)
R.gPad.SetLogz(1)
can2
# Out:
# Canvas('a5e4d3484f064c85b29b98271f9e50c0')
