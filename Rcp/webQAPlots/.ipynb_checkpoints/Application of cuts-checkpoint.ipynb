# %%
#include "base.C"

# %%
setColors();
hFile = new TFile( "auau14p5_bbc_mb_qa.root" );
TCanvas*c = new TCanvas( "imgExport", "img", 696, 472 );
# Out:
# Setting Colors

# %%
gStyle->SetOptStat( 1110 );

# %%
TPaveStats *s;
TEllipse * circ;
TH1 * h;
TLine * line;

# %%
h =  get2D( "event_pre_vX_vY" );
h = (TH2D*)h->Clone( "hrebin" );
((TH2D*)h)->RebinX(3);
((TH2D*)h)->RebinY(3);

h->Draw("col");
h->SetTitle( "Vertex XY Au+Au #sqrt{s_{NN}} = 14.5 GeV; vertex X [cm]; vertex Y[cm]" );

circ = new TEllipse( 0, 0, 1.0 );
circ->Draw("same");
circ->SetLineColor( kRed );
circ->SetFillStyle(0);
circ->SetLineWidth(2);

c->SetLogz(1);
c->SetLogy(0);
c->SetLogx(0);
c->Draw();

s = (TPaveStats*) gPad->GetPrimitive("stats");
s->SetX1NDC( 0.1 );
s->SetX2NDC( 0.4 );
s->SetY1NDC( 0.1 );
s->SetY2NDC( 0.3 );


c->Draw();
c->Print( "xy_vertex.png" );
c->Print( "xy_vertex.pdf" );
# Out:
# Info in <TCanvas::Print>: png file xy_vertex.png has been created
# Info in <TCanvas::Print>: pdf file xy_vertex.pdf has been created

# %%
h =  get2D( "event_pre_vZ" );
h->Draw("");
h->SetTitle( "Vertex Z Au+Au #sqrt{s_{NN}} = 14.5 GeV; vertex Z [cm]; dN/dvZ" );
h->GetXaxis()->SetRangeUser( -100, 100 );

h->SetFillStyle(1001 );
h->SetFillColor( kBlue - 7 );

line = new TLine( -30, 0, -30, 6e5 );
line->SetLineColor( kRed );
line->SetLineWidth( 2 );
line->Draw("same");

line = new TLine( 30, 0, 30, 6e5 );
line->SetLineColor( kRed );
line->SetLineWidth( 2 );
line->Draw("same");

c->SetLogy();
c->Draw();
s = (TPaveStats*) gPad->GetPrimitive("stats");
s->SetX1NDC( 0.6 );
s->SetX2NDC( 0.9 );
s->SetY1NDC( 0.7 );
s->SetY2NDC( 0.9 );

c->Print( "z_vertex.png" );
c->Print( "z_vertex.pdf" );
# Out:
# Info in <TCanvas::Print>: png file z_vertex.png has been created
# Info in <TCanvas::Print>: pdf file z_vertex.pdf has been created

# %%
h =  get2D( "event_pre_nTofMatchA" );
h->Draw("");
h->SetTitle( "# TOF Matched Tracks Au+Au #sqrt{s_{NN}} = 14.5 GeV; # TOF Matched Tracks; dN/dTOF" );
h->GetXaxis()->SetRangeUser( 0, 500 );


line = new TLine( 3, 0, 3, 1e8 );
line->SetLineColor( kRed );
line->SetLineWidth( 2 );
line->Draw("same");

c->SetLogy();
c->SetLogx(0);

c->Draw();
s = (TPaveStats*) gPad->GetPrimitive("stats");
s->SetX1NDC( 0.6 );
s->SetX2NDC( 0.9 );
s->SetY1NDC( 0.7 );
s->SetY2NDC( 0.9 );

c->Print( "nTofMatch.png" );
# Out:
# Info in <TCanvas::Print>: png file nTofMatch.png has been created

# %%
h =  get2D( "event_pre_nTofMatchA_corrRefMult" );

h = (TH2D*)h->Clone( "hrebin" );
((TH2D*)h)->RebinX(3);
((TH2D*)h)->RebinY(3);


h->Draw("col");
h->SetTitle( "Vertex XY Au+Au #sqrt{s_{NN}} = 14.5 GeV; # Tof-Matched Tracks; RefMult " );

h->GetXaxis()->SetRangeUser( 1, 500 );

c->Draw();

vLine( h, 3, kRed, 5 );

c->SetLogz(1);
c->SetLogy(1);
c->SetLogx(1);
c->Draw();

s = (TPaveStats*) gPad->GetPrimitive("stats");
s->SetX1NDC( 0.6 );
s->SetX2NDC( 0.9 );
s->SetY1NDC( 0.1 );
s->SetY2NDC( 0.3 );

c->Draw();
c->Print( "refmult_tofmatch.png" );
c->Print( "refmult_tofmatch.pdf" );
# Out:
# Info in <TCanvas::Print>: png file refmult_tofmatch.png has been created
# Info in <TCanvas::Print>: pdf file refmult_tofmatch.pdf has been created

# %%
h =  get2D( "track_pre_nHitsFit" );
h->Draw("h");
h->SetTitle( "# of TPC Fit Points Au+Au #sqrt{s_{NN}} = 14.5 GeV; # Fit Points; dN/dNHFit" );
h->GetYaxis()->SetRangeUser( 0, 100e6 );
h->SetFillStyle(1001 );
h->SetFillColor( kBlue - 7 );
c->Draw();

line = new TLine( 16, 0, 16, 60e6 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");


c->SetLogz(0);
c->SetLogy(0);
c->SetLogx(0);
c->Draw();



s = (TPaveStats*) gPad->GetPrimitive("stats");
topLeft( s );

c->Draw();
c->Print( "fit_points.png" );
c->Print( "fit_points.pdf" );
# Out:
# Error in <THistPainter::PaintInit>: Cannot set Y axis to log scale
# Info in <TCanvas::Print>: png file fit_points.png has been created

# %%
h =  get2D( "track_pre_nHitsFitOverPoss" );
h->Draw("h");
h->GetYaxis()->SetTitleOffset( 1.3 );
h->SetTitle( "# of Hits Fit / Possible Au+Au #sqrt{s_{NN}} = 14.5 GeV; # Hits Fit / Possible Points; dN/dNHFitRatio" );
h->GetYaxis()->SetRangeUser( 0, 2e8 );
h->SetFillStyle(1001 );
h->SetFillColor( kBlue - 7 );
c->Draw();

line = new TLine( 0.52, 0, 0.52, 60e6 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");


c->SetLogz(0);
c->SetLogy(0);
c->SetLogx(0);
c->Draw();



s = (TPaveStats*) gPad->GetPrimitive("stats");
topLeft( s );

c->Draw();
c->Print( "nfit_nposs.png" );
c->Print( "nfit_nposs.pdf" );
# Out:
# Info in <TCanvas::Print>: png file nfit_nposs.png has been created

# %%
h =  get2D( "track_pre_nHitsDedx" );
h->Draw("h");
h->GetYaxis()->SetTitleOffset( 1.3 );
h->SetTitle( "# of Hits dEdx Au+Au #sqrt{s_{NN}} = 14.5 GeV; # Hits dEdx; dN/dNHdEdx" );
h->GetYaxis()->SetRangeUser( 0, 2e8 );
h->SetFillStyle(1001 );
h->SetFillColor( kBlue - 7 );
c->Draw();

line = new TLine( 11, 0, 11, 60e6 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");


c->SetLogz(0);
c->SetLogy(0);
c->SetLogx(0);
c->Draw();



s = (TPaveStats*) gPad->GetPrimitive("stats");
topLeft( s );

c->Draw();
c->Print( "dedx_points.png" );
# Out:
# Info in <TCanvas::Print>: png file dedx_points.png has been created

# %%
h =  get2D( "track_pre_dca" );
h->Draw("h");
h->GetYaxis()->SetTitleOffset( 1.3 );
h->SetTitle( "Global DCA Au+Au #sqrt{s_{NN}} = 14.5 GeV; Global DCA [cm]; dN/dglobalDCA" );
h->GetXaxis()->SetRangeUser( 0, 5.5 );
h->GetYaxis()->SetRangeUser( 3e3, 3e9 );
h->SetFillStyle(1001 );
h->SetFillColor( kBlue - 7 );
c->Draw();


line = new TLine( 1.0, 3e3, 1.0, 2e9 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");


c->SetLogz(0);
c->SetLogy(1);
c->SetLogx(0);
c->Draw();



s = (TPaveStats*) gPad->GetPrimitive("stats");
topRight( s );

c->Draw();
c->Print( "dca.png" );
# Out:
# Info in <TCanvas::Print>: png file dca.png has been created

# %%
h =  get2D( "track_pre_ptRatio2D" );
h->Draw("col");
h->SetTitle( "pT Global vs. pT Primary #sqrt{s_{NN}} = 14.5 GeV; pT Primary [GeV/c]; pT Global [GeV/c]" );
h->GetYaxis()->SetTitleOffset( 1.3 );
h->GetXaxis()->SetRangeUser( 0, 500 );

c->Draw();

c->SetLogz(1);
c->SetLogy(0);
c->SetLogx(0);

line = new TLine( 0.0, 0.0, 5.0, 3.5 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");

line = new TLine( 0.0, 0.0, 3.5, 5.0 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");

s = (TPaveStats*) gPad->GetPrimitive("stats");
topLeft( s );

c->Draw();
c->Print( "ptpr_ptgl.png" );
# Out:
# Info in <TCanvas::Print>: png file ptpr_ptgl.png has been created

# %%
h =  get2D( "track_pre_yLocal" );
h->Draw("h");
h->GetYaxis()->SetTitleOffset( 1.3 );
h->SetTitle( "TOF yLocal Au+Au #sqrt{s_{NN}} = 14.5 GeV; yLocal [cm]; dN/dyLocal" );
h->GetXaxis()->SetRangeUser( -2.5, 2.5 );
h->GetYaxis()->SetRangeUser( 0, 3e7 );
h->SetFillStyle(1001 );
h->SetFillColor( kBlue - 7 );
c->Draw();


line = new TLine( -1.6, 0, -1.6, 2e7 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");

line = new TLine( 1.6, 0, 1.6, 2e7 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");


c->SetLogz(0);
c->SetLogy(0);
c->SetLogx(0);
c->Draw();



s = (TPaveStats*) gPad->GetPrimitive("stats");
topRight( s );

c->Draw();
c->Print( "ylocal.png" );
# Out:
# Info in <TCanvas::Print>: png file ylocal.png has been created

# %%
h =  get2D( "track_pre_zLocal" );
h->Draw("h");
h->GetYaxis()->SetTitleOffset( 1.3 );
h->SetTitle( "TOF zLocal Au+Au #sqrt{s_{NN}} = 14.5 GeV; zLocal [cm]; dN/dzLocal" );
h->GetXaxis()->SetRangeUser( -3.5, 3.5 );
h->GetYaxis()->SetRangeUser( 0, 1.3e7 );
h->SetFillStyle(1001 );
h->SetFillColor( kBlue - 7 );
c->Draw();


line = new TLine( -2.8, 0, -2.8, 1e7 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");

line = new TLine( 2.8, 0, 2.8, 1e7 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");


c->SetLogz(0);
c->SetLogy(0);
c->SetLogx(0);
c->Draw();



s = (TPaveStats*) gPad->GetPrimitive("stats");
topRight( s );

c->Draw();
c->Print( "zlocal.png" );
# Out:
# Info in <TCanvas::Print>: png file zlocal.png has been created

# %%
hFile->ls()
# Out:
# TFile**		auau14p5_bbc_mb_qa.root
#  TFile*		auau14p5_bbc_mb_qa.root
#   OBJ: TH2F	event_pre_vX_vY	Vertex XY Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x55c1930
#   OBJ: TH1F	event_pre_vZ	Vertex Z Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x71b8860
#   OBJ: TH1F	event_pre_nTofMatchA	# TOF Matched Tracks Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x770e2b0
#   OBJ: TH2F	event_pre_nTofMatchA_corrRefMult	Vertex XY Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x772b570
#   OBJ: TH1F	track_pre_nHitsFit	# of TPC Fit Points Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x7731090
#   OBJ: TH1F	track_pre_nHitsFitOverPoss	# of Hits Fit / Possible Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x74a6940
#   OBJ: TH1F	track_pre_nHitsDedx	# of Hits dEdx Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x7829590
#   OBJ: TH1F	track_pre_dca	# of Hits dEdx Au+Au #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x783d970
#   OBJ: TH2F	track_pre_ptRatio2D	pT Global vs. pT Primary #sqrt{s_{NN}} = 14.5 GeV : 0 at: 0x7282960
# ...
