# %%
#include "base.C"

# %%
setColors();
hFile = new TFile( "auau14p5_bbc_mb_qa_w_m2.root" );
TCanvas*c = new TCanvas( "imgExport", "img", 696, 472 );
# Out:
# Setting Colors

# %%
gStyle->SetOptStat( 1110 );

# %%
TPaveStats *s;
TEllipse * circ;
TH1 * h;
TLine * line;

# %%
h =  get2D( "track_pre_zLocal_m2" );
h->Draw("col");
h->SetTitle( "M^{2} vs. zLocal #sqrt{s_{NN}} = 14.5 GeV; zLocal [cm]; M^2 [GeV/c^{2}]^{2}" );
h->GetYaxis()->SetTitleOffset( 1.3 );
h->GetXaxis()->SetRangeUser( -3.5, 3.5 );
h->GetYaxis()->SetRangeUser( 0, 1.2 );

c->Draw();

c->SetLogz(1);
c->SetLogy(0);
c->SetLogx(0);

line = new TLine( 2.8, 0.0, 2.8, 1.2 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");

line = new TLine( -2.8, 0.0, -2.8, 1.2 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");
gStyle->SetOptStat(0);

c->Draw();
c->Print( "mass2_zlocal.png" );
c->Print( "mass2_zlocal.pdf" );
# Out:
# Info in <TCanvas::Print>: png file mass2_zlocal.png has been created
# Info in <TCanvas::Print>: pdf file mass2_zlocal.pdf has been created

# %%
h =  get2D( "track_pre_yLocal_m2" );
h->Draw("col");
h->SetTitle( "M^{2} vs. yLocal #sqrt{s_{NN}} = 14.5 GeV; zLocal [cm]; M^2 [GeV/c^{2}]^{2}" );
h->GetYaxis()->SetTitleOffset( 1.3 );
h->GetXaxis()->SetRangeUser( -2.5, 2.5 );
h->GetYaxis()->SetRangeUser( 0, 1.2 );

c->Draw();

c->SetLogz(1);
c->SetLogy(0);
c->SetLogx(0);

line = new TLine( 1.6, 0.0, 1.6, 1.2 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");

line = new TLine( -1.6, 0.0, -1.6, 1.2 );
line->SetLineColor( kRed );
line->SetLineWidth( 4 );
line->Draw("same");
gStyle->SetOptStat(0);

c->Draw();
c->Print( "mass2_ylocal.png" );
c->Print( "mass2_ylocal.pdf" );
# Out:
# Info in <TCanvas::Print>: png file mass2_ylocal.png has been created
# Info in <TCanvas::Print>: pdf file mass2_ylocal.pdf has been created

# %%
hFile->ls()
# Out:
# TFile**		auau14p5_bbc_mb_qa_w_m2.root
#  TFile*		auau14p5_bbc_mb_qa_w_m2.root
#   KEY: TH1I	event_cuts;1	Event Cuts
#   KEY: TH1I	event_single_cuts;1	Event Single Cuts
#   KEY: TH2I	bad_run_ids;1	Bad Runs
#   KEY: TH2I	good_run_ids;1	Good Runs
#   KEY: TH1F	event_nTrack_refMult;1	nTrack vs. RefMult
#   KEY: TH1F	event_pre_refMult;1	Pre Raw RefMult
#   KEY: TH1F	event_refMult;1	Raw RefMult
#   KEY: TH1F	event_corrRefMult;1	Corr RefMult
#   KEY: TH2F	event_corrRefMult_bin9;1	Corr RefMult vs. bin9
#   KEY: TH2F	event_corrRefMult_bin16;1	Corr RefMult vs. bin16
#   KEY: TH1F	event_refMultBins;1	Corr RefMult Bins
#   KEY: TH1F	event_refMultBinsUnweighted;1	Corr RefMult Bins (Unweighted)
#   KEY: TH1F	event_pre_vZ;1	pre vZ
#   KEY: TH1F	event_vZ;1	vZ
#   KEY: TH2F	event_pre_vX_vY;1	pre vX vY
#   KEY: TH2F	event_vX_vY;1	vX vY
#   KEY: TH1F	event_pre_vR;1
#   KEY: TH1F	event_vR;1
#   KEY: TH1F	event_pre_nTofMatchA;1
#   KEY: TH1F	event_nTofMatchA;1
# ...
