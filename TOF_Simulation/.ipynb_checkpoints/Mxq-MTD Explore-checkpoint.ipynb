# %%
# %run 'lib.ipynb'
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
chain = R.TChain( "mxq" )
chain.Add( "mxq_trg.root" )
# Out:
# 1

# %%
chain.Draw( "fastTdcWest - fastTdcEast", "fastTdcEast>300 && fastTdcWest>300" )
c1
# Out:
# Canvas('Canvas_FHVoYWkYpzrLgcokgaupR4')

# %%
hpx = h.ProfileX()
hpx.GetXaxis().SetRangeUser( -5, 5 )
hpx.Fit( "pol1" )
c1
# Out:
# Canvas('Canvas_ChoKtSNpn3sewgboayQH8N')

# %%
chain.Draw( "fastTdcWest - fastTdcEast" )
c1
# Out:
# Canvas('Canvas_LiifKwnFvwSfRzaJKtS5WS')

# %%
(1.0 / 3.362) * 2 / 29.97
# Out:
# 0.019849315903252052

# %%
chain.Draw( "tdcWest[12]>>h( 500 )", "run > 17043000" )


c1
# Out:
# Canvas('Canvas_ChoKtSNpn3sewgboayQH8N')
