# %%
# %run '../rootlib.ipynb'
chain = R.TChain( "bbq" )
chain.Add( "/Users/danielbrandenburg/bnl/local/work/vpdTriggerSlewPicoDstMaker/bin/bbq.root" )
# Out:
# 1

# %%
c1 = Canvas( width = 1000, height = 600 )

# %%
chain.Draw( "fastTdcWest - fastTdcEast : vertexZ >> vZ2( 20, -10, 10, 40, -20, 20 )", "fastAdcEast>10 && fastAdcWest>10", "colz" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "29.979 * 0.0188 * (fastTdcWest - fastTdcEast)/2.0 - vertexZ >> vZ( 30, -15, 15 )", "fastAdcEast>10 && fastAdcWest>10", "colz" )
R.gStyle.SetOptFit(111)
vZ = R.gDirectory.Get( "vZ" )
vZ.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcEast[fastChEast] : fastTdcEast", "", "" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "29.979 * 0.0188 * 0.5 *((fastTdcWest - tdcWest[fastPulserChWest] ) - (fastTdcEast - tdcEast[fastPulserChEast]  ) ) - vertexZ >> vZcorr( 30, -30, 0) ", "fastAdcEast>10 && fastAdcWest>10 && fastPulserChWest == 12 && fastPulserChEast == 12", "colz" )
R.gStyle.SetOptFit(111)
vZcorr = R.gDirectory.Get( "vZcorr" )
vZcorr.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "29.979 * 0.0188 * (tdcWest[3] - tdcEast[3])/2.0 - vertexZ >> vZ( 30, -15, 15 )", "fastAdcEast>10 && fastAdcWest>10", "colz" )
R.gStyle.SetOptFit(111)
vZ = R.gDirectory.Get( "vZ" )
vZ.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "29.979 * 0.0188 * ((tdcWest[3] - tdcWest[0]) - (tdcEast[3] - tdcEast[0]))/2.0 - vertexZ >> vZ( 30, -115, -85 )", "fastAdcEast>10 && fastAdcWest>10", "colz" )
R.gStyle.SetOptFit(111)
vZ = R.gDirectory.Get( "vZ" )
vZ.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "fastTdcEast : tdcEast[ fastPulserChEast ] >> h2( 50, 2050, 210, 100, 900, 1100 )", "", "col" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
def findMean( tube, side ) :
    chain.Draw( "tdc" + side + "[" + str(tube) + "] >> temp( 400, 800, 1200 )", "tdc" + side + "[" + str(tube) + "] > 300 && adc" + side + "[" + str(tube) + "] > 10" )
    temp = R.gDirectory.Get( "temp" )
    temp.Fit( "gaus" )
    return c1



findMean( 1, "East" )
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
findMean( 2, "East" )
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
findMean( 3, "East" )
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcEast[0] >> h0( 100, 2050, 2150 )", "tdcEast[0] > 300 && adcEast[0] > 10" )
h0 = R.gDirectory.Get( "h0" )
h0.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcEast[4] >> h0( 100, 2350, 2450 )", "tdcEast[4] > 300 && adcEast[4] > 10" )
h0 = R.gDirectory.Get( "h0" )
h0.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcEast[8] >> h0( 100, 2300, 2400 )", "tdcEast[8] > 300 && adcEast[8] > 10" )
h0 = R.gDirectory.Get( "h0" )
h0.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcEast[12] >> h12( 100, 2030, 2130 )", "tdcEast[12] > 300 && adcEast[12] > 10" )
h12 = R.gDirectory.Get( "h12" )
h12.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
findMean( 13, "East" )
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
findMean( 5, "West" )
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcWest[0] >> h12( 100, 2390, 2490 )", "tdcWest[0] > 300 && adcWest[0] > 10" )
h12 = R.gDirectory.Get( "h12" )
h12.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcWest[4] >> h12( 100, 2275, 2375 )", "tdcWest[4] > 300 && adcWest[4] > 10" )
h12 = R.gDirectory.Get( "h12" )
h12.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcWest[8] >> h12( 100, 2250, 2350 )", "tdcWest[8] > 300 && adcWest[8] > 10" )
h12 = R.gDirectory.Get( "h12" )
h12.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcWest[12] >> h12( 100, 2150, 2250 )", "tdcWest[12] > 300 && adcWest[12] > 10" )
h12 = R.gDirectory.Get( "h12" )
h12.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
findMean( 14, "West" )
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
2083 - 1013
# Out:
# 1070

# %%
2386 - 1013
# Out:
# 1373

# %%
2351 - 1013
# Out:
# 1338

# %%
2083 - 1013
# Out:
# 1070

# %%
2441 - 1013
# Out:
# 1428

# %%
2330 - 1013
# Out:
# 1317

# %%
2292 - 1013
# Out:
# 1279

# %%
2173 - 1013
# Out:
# 1160
