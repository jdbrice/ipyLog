# %%
# %run '../rootlib.ipynb'
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
chain = R.TChain( "bbq" )
chain.Add( "bbq.root" )
# Out:
# 1

# %%
c1 = Canvas( width=1000, height=500 )

# %%
def adcE( tube ):
    return "adcEast[" + str(tube) + "]"
def tdcE( tube ):
    return "tdcEast[" + str(tube) + "]"
def safeE( tubes ):
    ss = ""
    for tube in tubes :
        ss += tdcE( tube ) + " > 150 && " + adcE( tube ) + " > 10 &&"
    ss += "1"
    return ss
def adcW( tube ):
    return "adcWest[" + str(tube) + "]"
def tdcW( tube ):
    return "tdcWest[" + str(tube) + "]"
def safeW( tubes ):
    ss = ""
    for tube in tubes :
        ss += tdcW( tube ) + " > 150 && " + adcW( tube ) + " > 10 &&"
    ss += "1"
    return ss

# %%
chain.Draw( tdcE(1) +"-" + tdcE(2) +">>htest", safeE([1, 2]), "h" )
htest = R.gDirectory.Get( "htest" )
R.gStyle.SetOptFit(111)
ff = R.TF1( "fgaus", "gaus" )
htest.Fit( ff )
print( ff.GetParameter( 0 ) )
print( ff.GetParameter( 1 ) )
print( ff.GetParameter( 2 ), "+/-", ff.GetParError( 2 ) )

c1
# Out:
# 30078.1285894
# 0.586945545245
# (13.300480348325902, '+/-', 0.044838664863440236)
# Canvas('Canvas_4uRuCLkGBTE8TFfiQLaxRi')

# %%
def sigma_diff_E( tubeA, tubeB ) :
    chain.Draw( tdcE(tubeA) +"-" + tdcE(tubeB) +">>temp(400, -200, 200)", safeE([tubeA, tubeB]), "h" )
    temp = R.gDirectory.Get( "temp" )
    ff = R.TF1( "fgaus", "gaus" )
    temp.Fit( ff )
    return ( ff.GetParameter( 2 ), ff.GetParError( 2 ) )
def sigma_diff_W( tubeA, tubeB ) :
    chain.Draw( tdcW(tubeA) +"-" + tdcW(tubeB) +">>temp(400, -200, 200)", safeE([tubeA, tubeB]), "h" )
    temp = R.gDirectory.Get( "temp" )
    ff = R.TF1( "fgaus", "gaus" )
    temp.Fit( ff )
    return ( ff.GetParameter( 2 ), ff.GetParError( 2 ) )

# %%
sigma_diff_E( 1, 2 )
# Out:
# (12.19905092220047, 0.04258400767809167)

# %%
def make_sigma_plot( tubeA ) :
    hSigmas = R.TH1D( "sigmas_" + str(tubeA), "sigmas " + str(tubeA) + "; TubeB; sigma( TubeA - tubeB )", 20, 0, 20 )
    for tB in range( 0, 16 ) :
        if tB == tubeA : continue
        if tB == 0 or tB == 4 or tB == 8 or tB ==12 : continue
            
        sig = sigma_diff_E( tubeA, tB )
        hSigmas.SetBinContent( tB+1, sig[0] )
        hSigmas.SetBinError( tB+1, sig[1] )
        
    return hSigmas

# %%
hsig1 = make_sigma_plot( 1 )
hsig2 = make_sigma_plot( 2 )
hsig3 = make_sigma_plot( 3 )
hsig1.Draw( "pe")
hsig2.Draw( "pe same")
hsig3.Draw( "pe same")
c1
# Out:
# Canvas('Canvas_4uRuCLkGBTE8TFfiQLaxRi')

# %%
hsig5 = make_sigma_plot( 5 )
hsig6 = make_sigma_plot( 6 )
hsig7 = make_sigma_plot( 7 )
hsig5.Draw( "pe")
hsig6.Draw( "pe same")
hsig7.Draw( "pe same")
c1
# Out:
# Canvas('Canvas_4uRuCLkGBTE8TFfiQLaxRi')

# %%
hsig9 = make_sigma_plot( 9 )
hsig10 = make_sigma_plot( 10 )
hsig11 = make_sigma_plot( 11 )
hsig9.Draw( "pe")
hsig10.Draw( "pe same")
hsig11.Draw( "pe same")
c1
# Out:
# Canvas('Canvas_4uRuCLkGBTE8TFfiQLaxRi')

# %%
hsig13 = make_sigma_plot( 13 )
hsig14 = make_sigma_plot( 14 )
hsig15 = make_sigma_plot( 15 )
hsig13.Draw( "pe")
hsig14.Draw( "pe same")
hsig15.Draw( "pe same")
c1
# Out:
# Canvas('Canvas_4uRuCLkGBTE8TFfiQLaxRi')

# %%
import numpy as np

# %%
np.sqrt( 28**2 + 18**2 )
# Out:
# 33.286633954186478

# %%
chain.Draw( tdcW(3) + "-" + tdcE(1) + ">> hNominal( 100, -45, 55 )", safeW( [3]) + " && " + safeE([1]), "h" )
R.gStyle.SetOptFit( 111 )
hNominal = R.gDirectory.Get( "hNominal" )
hNominal.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_SviY78qM9tJ6EYoxGrvkmU')

# %%
chain.Draw( "(" + tdcW(3) + "-" + tdcW(0) + ")-(" + tdcE(1) + "-" + tdcE(0) + ")>>hNoise( 100, -400, -300 )", safeW( [3]) + " && " + safeE([1]), "h" )
hNoise = R.gDirectory.Get( "hNoise" )
hNoise.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_SviY78qM9tJ6EYoxGrvkmU')

# %%
chain.Draw( tdcE(12), safeE([12]), "h" )  
c1
# Out:
# Canvas('Canvas_SviY78qM9tJ6EYoxGrvkmU')

# %%
chain.Draw( tdcW(12), safeW([12]), "h" )  
c1
# Out:
# Canvas('Canvas_SviY78qM9tJ6EYoxGrvkmU')

# %%
chain.Draw( tdcE(0) +":" + tdcE(1) +">>H2( 100, 900, 1100, 20, 2060, 2100 )", safeE( [0, 1] ), "col" )
c1
# Out:
# Canvas('Canvas_SviY78qM9tJ6EYoxGrvkmU')

# %%
hh2 = R.gDirectory.Get( "H2" )
ph2 = hh2.ProfileX()
ph2.Draw()
c1
# Out:
# Canvas('Canvas_SviY78qM9tJ6EYoxGrvkmU')

# %%
chain.Draw( tdcE(1), safeE( [0, 1] ), "col" )
c1
# Out:
# Canvas('Canvas_SviY78qM9tJ6EYoxGrvkmU')

# %%
np.sqrt( 30**2 + 18**2)
# Out:
# 34.985711369071801
