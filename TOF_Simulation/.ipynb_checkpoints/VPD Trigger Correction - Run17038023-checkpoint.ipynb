# %%
# %run '../rootlib.ipynb'
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
chain = R.TChain( "tof" )

# %%
chain.Add( "/Users/danielbrandenburg/bnl/local/work/TofPicoDstMaker/bin/out/*.root" )
# Out:
# 2

# %%
can = Canvas( width=1100, height=500 )
can.Divide( 2, 1 )

# %%
def tdcE( i ) :
    return "vpdBbqTdcEast[" + str(i) + "]"
def tdcW( i ) :
    return "vpdBbqTdcWest[" + str(i) + "]"
def safeE( l ) :
    safety = ""
    for i in l :
        safety += tdcE( i ) + " > 150 && "
    safety += "1"
    return safety

def safeW( l ) :
    safety = ""
    for i in l :
        safety += tdcW( i ) + " > 150 && "
    safety += "1"
    return safety

# %%
safeE( [4, 5, 6] )
# Out:
# 'vpdBbqTdcEast[4] > 150 && vpdBbqTdcEast[5] > 150 && vpdBbqTdcEast[6] > 150 && 1'

# %%
can = Canvas( width=1100, height=2000 )
can.Divide( 1, 4 )
can.cd(1)
chain.Draw( tdcE(0) + ">>hTdcE0", safeE([0]), "h" )
mTdcE0 = R.gDirectory.Get( "hTdcE0" ).GetMean()
can.cd(2)
chain.Draw( tdcE(4) + ">>hTdcE4", safeE([4]), "h" )
mTdcE4 = R.gDirectory.Get( "hTdcE4" ).GetMean()
can.cd(3)
chain.Draw( tdcE(8) + ">>hTdcE8", safeE([8]), "h" )
mTdcE8 = R.gDirectory.Get( "hTdcE8" ).GetMean()
can.cd(4)
chain.Draw( tdcE(12) + ">>hTdcE12", safeE([12]), "h" )
mTdcE12 = R.gDirectory.Get( "hTdcE12" ).GetMean()
print mTdcE0, mTdcE4, mTdcE8, mTdcE12
# Out:
# 2082.43373696 2385.50298532 2350.43027733 2082.9758942

# %% [markdown]
# ## East Channel Pulsers

# %%
can
# Out:
# Canvas('Canvas_aiHCCn4aanT3QVvZi7DqiD')

# %%
can = Canvas( width=1100, height=2000 )
can.Divide( 1, 4 )
can.cd(1)
chain.Draw( tdcW(0) + ">>hTdcW0", safeW([0]), "h" )
mTdcW0 = R.gDirectory.Get( "hTdcW0" ).GetMean()
can.cd(2)
chain.Draw( tdcW(4) + ">>hTdcW4", safeW([4]), "h" )
mTdcW4 = R.gDirectory.Get( "hTdcW4" ).GetMean()
can.cd(3)
chain.Draw( tdcW(8) + ">>hTdcW8", safeW([8]), "h" )
mTdcW8 = R.gDirectory.Get( "hTdcW8" ).GetMean()
can.cd(4)
chain.Draw( tdcW(12) + ">>hTdcW12", safeW([12]), "h" )
mTdcW12 = R.gDirectory.Get( "hTdcW12" ).GetMean()

# %% [markdown]
# ## West Channel Pulsers

# %%
can
# Out:
# Canvas('Canvas_3wSMiR3bnzGnMrrLmS7uRJ')

# %%
can = Canvas( width=1100, height=1000 )
can.Divide( 1, 2 )

# %%
can.cd(1)
chain.Draw( tdcW(3) + ">>before", safeW([ 0, 3]), "h" )
can.cd(2)
chain.Draw( tdcW(3) + "-" +  tdcW(0) + " + " + str( mTdcW0 ) +">>after" , safeW([0, 3]), "h" )
can
# Out:
# Canvas('Canvas_evagBENPSmDsrp4ntcECCd')

# %%
R.gDirectory.Get( "before" ).Fit( "gaus" )
R.gDirectory.Get( "after" ).Fit( "gaus" )
can
# Out:
# Canvas('Canvas_evagBENPSmDsrp4ntcECCd')
