# %%
# %run '../rootlib.ipynb'
chain = R.TChain( "bbq" )
chain.Add( "/Users/danielbrandenburg/bnl/local/work/vpdTriggerSlewPicoDstMaker/bin/bbq.root" )
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# 1

# %%
c1 = Canvas( width=1000, height=500 )

# %%
def tdcE( tube ):
    return "tdcEast[" + str(tube) + "]"
def safeE( tubes ):
    ss = ""
    for tube in tubes :
        ss += tdcE( tube ) + " > 150 && "
    ss += "1"
    return ss
def tdcW( tube ):
    return "tdcWest[" + str(tube) + "]"
def safeW( tubes ):
    ss = ""
    for tube in tubes :
        ss += tdcW( tube ) + " > 150 && "
    ss += "1"
    return ss

# %%
chain.Draw( "fastTdcEast" )
c1
# Out:
# Canvas('Canvas_VUwqUKBtWwjEuE5mYptsRY')

# %%
chain.Draw( "fastTdcEast : " + tdcE(12) + "Hcorr>>(  )", safeE([0]), "col"  )
c1
# Out:
# Canvas('Canvas_VUwqUKBtWwjEuE5mYptsRY')

# %%
chain.Draw( "fastTdcWest - fastTdcEast + 4096>> hVzTac( 60, 4066, 4126 )", " fastTdcEast>150 && fastTdcWest>150", "h" )
c1
# Out:
# Canvas('Canvas_VUwqUKBtWwjEuE5mYptsRY')

# %%
4096 - 30
# Out:
# 4066

# %%
4096 - 4082
# Out:
# 14

# %%
1.0 / 0.02
# Out:
# 50.0

# %%
50 * 20 / 60.0
# Out:
# 16.666666666666668
