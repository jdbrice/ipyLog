# %%
# %run 'lib.ipynb'

# %%
chain = R.TChain( "mxq" )
chain.Add( "mxq_mtd.root" )
# Out:
# 1

# %%
c1 = Canvas( width=800, height=800 )
chain.Draw( "(fastTdcWest - fastTdcEast)+4096>>hTAC( 200, 3800, 4400 )", "fastTdcWest>300 && fastTdcEast>300 && fastAdcEast>10 && fastAdcWest>10", "h" )
rget( "hTAC" ).Fit("gaus", "R", "", 4000, 4200 )
c1
# Out:
# Canvas('Canvas_scu4XRw6iMjuPHupWn4Rdj')

# %%
chain.Draw( "0.5 * (fastTdcWest - fastTdcEast) * 0.01888 * 29.979 - vertexZ>>deltaVz( 100, -50, 50 )", "fastTdcWest>300 && fastTdcEast>300 && fastAdcEast>10 && fastAdcWest>10", "h" ) 
c1
# Out:
# Canvas('Canvas_pu2hjSC8uzFwYcwN3bYoTh')

# %%
chain.Draw( "(fastTdcWest - fastTdcEast) * 0.5 * 0.01888 * 29.979 - vertexZ", "fastTdcWest > 300 && fastTdcEast > 300" )
c1
# Out:
# Canvas('Canvas_Y7bWTEubFbJnTgYQ3HRoiZ')

# %%
(1.0 / 3.362) * 2 / 29.97
# Out:
# 0.019849315903252052

# %%
chain.Draw( "tdcWest[4]>>h( 500 )" )


c1
# Out:
# Canvas('Canvas_Y7bWTEubFbJnTgYQ3HRoiZ')

# %%
c46 = R.TChain( "mxq" )
c46.Add( "mxq_046.root" )
# Out:
# 1

# %%
c46.Draw( "(fastTdcWest - fastTdcEast)/2.0 * 0.01888 * 29.979- vertexZ>>hTAC46( 40, -20, 20 ) ", "fastTdcWest>300 && fastTdcEast>300 && fastAdcEast>10 && fastAdcWest>10", "h" )
rget("hTAC46").Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_Y7bWTEubFbJnTgYQ3HRoiZ')

# %%
chain.Draw( "vertexZ", "fabs(0.5 * (fastTdcWest - fastTdcEast) * 0.01888 * 29.979) - vertexZ < 3 ", "h" )
c1
# Out:
# Canvas('Canvas_pu2hjSC8uzFwYcwN3bYoTh')

# %%
(12.62 / 2.0) * 0.5666
# Out:
# 3.575246

# %%
(6.5 * 0.566)
# Out:
# 3.679

# %%
(18.62/2.0) * 0.56
# Out:
# 5.2136000000000005

# %%
(12.67 / 2.0) * 0.5666
# Out:
# 3.589411

# %%
cc = R.TChain( "bbq" )
cc.Add( "bbq.root")
# Out:
# 1

# %%
cc.Draw( "(fastTdcWest-fastTdcEast)*0.5 * 0.0188 * 29.979 - vertexZ>>h(100, -10, 10)", "fastTdcEast>300 && fastTdcWest>300" )
c1
# Out:
# Canvas('Canvas_pu2hjSC8uzFwYcwN3bYoTh')

# %%
cc.Draw( "vertexZ" )
c1
# Out:
# Canvas('Canvas_pu2hjSC8uzFwYcwN3bYoTh')

# %%
cc.Draw( "29.979 * 0.0188 * ( fastTdcWest - fastTdcEast ) / 2.0 - vertexZ >> vZ( 30, -10, 12 )", "fastAdcEast>10 && fastAdcWest>10", "colz" )
c1
# Out:
# Canvas('Canvas_pu2hjSC8uzFwYcwN3bYoTh')

# %%
import numpy as np

# %%
220 / np.sqrt( 12 )
# Out:
# 63.508529610858837

# %%
0.063 * 29.979
# Out:
# 1.888677
