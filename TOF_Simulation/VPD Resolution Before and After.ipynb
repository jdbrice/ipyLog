# %%
# %run '../rootlib.ipynb'
chain = R.TChain( "bbq" )
chain.Add( "/Users/danielbrandenburg/bnl/local/work/vpdTriggerSlewPicoDstMaker/bin/bbq.root" )
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# 1

# %%
c1 = Canvas( width = 1000, height = 600 )

# %%
chain.Draw( "29.979 * 0.0188 * (fastTdcWest - fastTdcEast)/2.0 - vertexZ >> vZ(20 , -8, 12 )", "fastAdcEast>10 && fastAdcWest>10", "colz" )
R.gStyle.SetOptFit(111)
vZ = R.gDirectory.Get( "vZ" )
vZ.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_AFbc58xYGHcnQmuh8cTQUb')

# %%
chain.Draw( "29.979 * 0.0188 *0.5 *((fastTdcWest - (tdcWest[fastPulserChWest] - 1013) ) - (fastTdcEast - (tdcEast[fastPulserChEast] - 1013)  ) ) - vertexZ >> vZcorr( 20, -8, 12) ", "fastAdcEast>10 && fastAdcWest>10 && fastPulserChWest == 12 ", "colz" )
R.gStyle.SetOptFit(111)
vZcorr = R.gDirectory.Get( "vZcorr" )
vZcorr.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_AFbc58xYGHcnQmuh8cTQUb')

# %%
chain.Draw( "29.979 * 0.0188 * 0.5 *((fastTdcWest - tdcWest[fastPulserChWest] ) - (fastTdcEast - tdcEast[fastPulserChEast]  ) ) - vertexZ >> vZcorr( 30, -30, 0) ", "fastAdcEast>10 && fastAdcWest>10 && fastPulserChWest == 12 && fastPulserChEast == 12", "colz" )
R.gStyle.SetOptFit(111)
vZcorr = R.gDirectory.Get( "vZcorr" )
vZcorr.Fit( "gaus" )
c1
# Out:
# Canvas('Canvas_dKc7qfbXRGYTKLyiZNN7CU')

# %%
chain.Draw( "tdcWest[fastPulserChWest] - 1013", "", "h")
c1
# Out:
# Canvas('Canvas_AFbc58xYGHcnQmuh8cTQUb')
