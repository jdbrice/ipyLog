# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
def impact( theta, r ) :
    return -r * np.cos( theta / 2 )

# %%
ts = np.linspace( -np.pi, np.pi )
plt.plot( ts, impact( ts, 1 ) )

# %%
def scatterTheta( b, r ):
    if np.absolute(b) <= r :
        return 2*np.arccos( b / r ) - np.pi
    return 0.0

xb = np.linspace( -1, 1, num=200 )
vst = np.vectorize( scatterTheta )
plt.plot( xb, vst( xb, 1 ) )

# %%
xb = np.linspace( -1.5, 1.5, num=200 )
vst = np.vectorize( scatterTheta )
plt.plot( xb, vst( xb, 1 ) )

# %%
thetas = []
impact = []
for x in range( 0, 10000 ) :
    b = np.random.random(  ) * 2 - 1
    thetas.append( scatterTheta( b, 1 ) )
    impact.append( b )
    
n, bins, patches = plt.hist(impact, 50, normed=1, facecolor='green', alpha=0.75)

# %%
plt.hist( thetas, 50 );

# %%
plt.hist( np.cos(thetas), 50 );

# %%
plt.hist( np.sin(thetas), 50 );

# %% [markdown]
# ## what is the point?
# This is not really about eleastic scattering
