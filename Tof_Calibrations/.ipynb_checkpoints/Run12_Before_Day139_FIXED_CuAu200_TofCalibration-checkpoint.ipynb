# %%
# load the functions resources making the plots
# %run 'libTofCalib.ipynb'

# %%
# file containg final pass for QA
f = ROOT.TFile( "/star/institutions/rice/jdb/calib/ntupler/qa.histo.root", "READ" )
# Crate a Root Canvas
c = ROOT.TCanvas( "c", "c", 1000, 500 )
ROOT.gStyle.SetOptStat( 0 )
# Out:
# ERROR:ROOT.TFile.Init:/star/institutions/rice/jdb/calib/ntupler/qa.histo.root not a ROOT file
# ---------------------------------------------------------------------------
# ROOTError                                 Traceback (most recent call last)
# <ipython-input-3-54112f3ca208> in <module>()
#       1
#       2 # file containg final pass for QA
# ----> 3 f = ROOT.TFile( "/star/institutions/rice/jdb/calib/ntupler/qa.histo.root", "READ" )
#       4 # Crate a Root Canvas
#       5 c = ROOT.TCanvas( "c", "c", 1000, 500 )
#
# /Users/danielbrandenburg/Library/Python/2.7/lib/python/site-packages/rootpy-dev-py2.7.egg/rootpy/__init__.pyc in __new__(self, *args, **kwargs)
#     239             class asrootpy_cls(result):
#     240                 def __new__(self, *args, **kwargs):
# --> 241                     return asrootpy(thing(*args, **kwargs), warn=warn)
#     242             asrootpy_cls.__name__ = '{0}_asrootpy'.format(thing.__name__)
#     243             return asrootpy_cls
#
# /Users/danielbrandenburg/Library/Python/2.7/lib/python/site-packages/rootpy-dev-py2.7.egg/rootpy/__init__.pyc in __new__(self, *args, **kwargs)
#     239             class asrootpy_cls(result):
#     240                 def __new__(self, *args, **kwargs):
# --> 241                     return asrootpy(thing(*args, **kwargs), warn=warn)
#     242             asrootpy_cls.__name__ = '{0}_asrootpy'.format(thing.__name__)
#     243             return asrootpy_cls
#
# /Users/danielbrandenburg/Library/Python/2.7/lib/python/site-packages/rootpy-dev-py2.7.egg/rootpy/logger/roothandler.pyc in python_logging_error_handler(level, root_says_abort, location, msg)
#     100             # Hence the need for dark magic, we re-raise it within a trace.
#     101             from .. import ROOTError
# --> 102             raise ROOTError(level, location, msg)
#     103         except RuntimeError:
#     104             _, exc, traceback = sys.exc_info()
#
# ROOTError: level=3000, loc='TFile::Init', msg='/star/institutions/rice/jdb/calib/ntupler/qa.histo.root not a ROOT file'

# %%
reportGeomY(f )

# %%
reportGeomZ( f )

# %%
reportVPD( f )
# Out:
# Canvas('c')

# %% [markdown]
# * The mean should be less than ~10 mm from being centered at 0
# * sigma varies depending on energy and species
#     * Run12 CuAu sigma = 0.72

# %%
hRes = f.BTofTimeRes_vs_TrayNarrow
fig = plt.figure(1, figsize=(19, 7))
shown = rplt.imshow( hRes, norm=LogNorm(vmin=1))
fig.colorbar(shown)
plt.xlabel("Tray")
plt.ylabel( r'TOF_{meas} - TOF_{exp} [ns]' )
plt.show()

# %%
c.Clear()
h = f.BTofTimeRes_vs_TrayNarrow.ProjectionY()
h.Fit( "gaus", "", "", -.65, -.4 )
h.SetMarkerStyle(8)
h.Draw("p")
c
# Out:
# Canvas('c')

# %%
reportPID(f)

# %%
c.Clear()
hPid = f.PID
hPid.GetXaxis().SetRange( 15, 250 )
hPid.GetYaxis().SetRange( 50, 350 )
hPid.Draw( "colz" )
ROOT.gPad.SetLogz(1)
c
# Out:
# Canvas('c')
