# %% [markdown]
# ### Calculating TOF Trigger Windows
# 1. Find some useable data after the VPD gain / trigger settings are complete
# 2. Run the RTS exampe code to build the tof tree
# 3. run the trigger window finder here

# %%
# %run 'trigger_window_lib.ipynb'

# %%
# defines the path to the data
path = "/Users/danielbrandenburg/bnl/local/work/calib/triggerWindow/"
# the run # of the data being investigated
# used for consistent naming throughout
rn = "16057052"
data = root_open( path + "tof_"+ rn +".root" )

# %%
makeReport()
# Out:
# WARNING:ROOT.Fit:Fit data is empty
# Generating PDF report at  triggerWindows_16057052.pdf
# tray
# WARNING:ROOT.Fit:Fit data is empty
#  38  is dead
# tray
# WARNING:ROOT.Fit:Fit data is empty
#  41  is dead
# tray  102  is dead
# Exporting trigger windows to  triggerWindows_16057052.dat

# %%
makeReportInline(0)
# Out:
# Canvas('43c3aa7e680a447c9128eecc6593293b')

# %%
makeReportInline(1)
# Out:
# Canvas('0d2c6e9f4da247b0808a41e0227537cc')

# %%
makeReportInline(2)
# Out:
# WARNING:ROOT.Fit:Fit data is empty
# WARNING:ROOT.Fit:Fit data is empty
# tray  38  is dead
# tray  41  is dead
# Canvas('999a0271626248a685ab75515abca8b5')

# %%
makeReportInline(3)
# Out:
# Canvas('fc72869859f84496bb4626fb4663ebd8')

# %%
makeReportInline(4)
# Out:
# Canvas('a2650b6f0d5a4ef4b9b0b26a647ace2d')

# %%
makeReportInline(5)
# Out:
# Canvas('a6a499cf723f47e4bae1c379fa864e26')

# %%
makeReportInline(6)
# Out:
# WARNING:ROOT.Fit:Fit data is empty
# tray  102  is dead
# Canvas('7ac7795689054eed92011a66ebc6b6d7')

# %%
makeReportInline(7)
# Out:
# WARNING:ROOT.Fit:Fit data is empty
# WARNING:ROOT.Fit:Fit data is empty
# WARNING:ROOT.Fit:Fit data is empty
# tray  123  is dead
# tray  124  is dead
# tray
# WARNING:ROOT.Fit:Fit data is empty
# WARNING:ROOT.Fit:Fit data is empty
#  125  is dead
# tray  126  is dead
# tray
# WARNING:ROOT.Fit:Fit data is empty
#  127  is dead
# tray  128  is dead
# Canvas('cfcc758acbe54919a436f21a20598e56')
