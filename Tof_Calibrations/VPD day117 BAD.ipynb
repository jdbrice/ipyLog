# %%
TFile * f = new TFile( "ntuple_d117_bad.root" )
# Out:
# (TFile *) 0x6efcdf0
# TClass::Init:0: RuntimeWarning: no dictionary for class StPicoEvent is available
# TClass::Init:0: RuntimeWarning: no dictionary for class StThreeVector<double> is available

# %%
vpdPico->Draw( "bbqTdcEast[0]>>pE1" );
pE1->Fit( "gaus" );
gStyle->SetOptFit(111);
# Out:
#  FCN=128.173 FROM MIGRAD    STATUS=CONVERGED      62 CALLS          63 TOTAL
#                      EDM=2.60474e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     4.35626e+02   4.88363e+00   2.20516e-02   7.05718e-07
#    2  Mean         8.13737e+02   1.00724e-01   5.58921e-04  -2.22175e-04
#    3  Sigma        1.10117e+01   7.21384e-02   9.78848e-06  -5.39595e-04

# %%
c1->Draw()

# %%
vpdPico->Draw( "bbqTdcEast[1] - bbqTdcEast[11]>>(40, -200, 200)", "bbqTdcEast[1]>180 && bbqTdcEast[11]>180" );
c1->Draw();

# %%
vpdPico->Draw( "bbqTdcEast - bbqTdcEast[11]: Iteration$ >> hEast( 16, 0, 16, 500, -250, 250 )", " bbqTdcEast > 180 && Iteration$ != 11 && Iteration$ %4 != 0", "colz" );
hEast->Fit("pol0");
c1->Draw();
c1->SetLogz(1);
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =   2.7265e+08
# NDf                       =         4111
# p0                        =    -0.533988   +/-   0.796177

# %%
vpdPico->Draw( "bbqTdcWest - bbqTdcEast[11]: Iteration$ >> hWest( 16, 0, 16, 500, -250, 250 )", "bbqTdcEast[11] > 180 && bbqTdcWest > 180 && Iteration$ != 11 && Iteration$ %4 != 0", "colz" );
hWest->Fit("pol0");
c1->Draw();

c1->SetLogz(1);
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =  3.10518e+08
# NDf                       =         3983
# p0                        =       16.835   +/-   0.93158

# %%
vpdPico->Draw( "bbqTdcEast[0]>>hPE1" );
hPE1->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=32.2902 FROM MIGRAD    STATUS=CONVERGED      59 CALLS          60 TOTAL
#                      EDM=5.47066e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     8.68020e+02   9.72084e+00   2.22179e-02  -4.13630e-06
#    2  Mean         8.13735e+02   1.01485e-01   3.88019e-04  -1.58845e-05
#    3  Sigma        1.11409e+01   7.33188e-02   5.00659e-06  -1.31234e-02

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcEast[4]>>hPE2" );
hPE2->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=29.331 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
#                      EDM=1.01614e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.32532e+02   8.15576e+00   1.78949e-02   6.30270e-07
#    2  Mean         1.03114e+03   1.20322e-01   4.91684e-04  -7.06181e-06
#    3  Sigma        1.32033e+01   8.53783e-02   4.72102e-06   2.05551e-03

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcEast[8]>>hPE3" );
hPE3->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=76.1388 FROM MIGRAD    STATUS=CONVERGED      52 CALLS          53 TOTAL
#                      EDM=1.35639e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.56694e+02   8.34509e+00   2.95391e-02  -6.82287e-06
#    2  Mean         9.91967e+02   1.16257e-01   4.98184e-04   4.15106e-05
#    3  Sigma        1.27324e+01   7.96537e-02   7.35615e-06  -2.61049e-02

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcEast[12]>>hPE4" );
hPE4->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=44.8571 FROM MIGRAD    STATUS=CONVERGED      59 CALLS          60 TOTAL
#                      EDM=3.43995e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.46169e+03   1.60497e+01   4.39339e-02  -3.62230e-06
#    2  Mean         7.78256e+02   1.21032e-01   3.98395e-04   5.33867e-05
#    3  Sigma        1.32178e+01   8.18553e-02   5.61848e-06  -4.82028e-02

# %% [markdown]
# ## West Pulsers

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[0]>>hPW1" );
hPW1->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=253.005 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
#                      EDM=6.03569e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     8.98286e+02   9.77602e+00   6.40977e-02  -5.30252e-06
#    2  Mean         1.11410e+03   2.52713e-01   1.89783e-03   2.14203e-04
#    3  Sigma        2.64401e+01   1.56685e-01   1.24909e-05  -5.11771e-02

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[4]>>hPW2" );
hPW2->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=164.737 FROM MIGRAD    STATUS=CONVERGED      62 CALLS          63 TOTAL
#                      EDM=6.26938e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.75228e+02   8.79309e+00   4.45160e-02   1.08586e-05
#    2  Mean         1.01953e+03   1.17833e-01   7.10163e-04   3.04183e-03
#    3  Sigma        1.23374e+01   8.33085e-02   1.09525e-05  -3.40426e-03

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[8]>>hPW3" );
hPW3->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=72.622 FROM MIGRAD    STATUS=CONVERGED      59 CALLS          60 TOTAL
#                      EDM=2.00438e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.40685e+03   1.55453e+01   5.36401e-02  -3.32553e-06
#    2  Mean         9.43117e+02   1.26569e-01   5.22529e-04   1.62340e-04
#    3  Sigma        1.36968e+01   8.59217e-02   7.08749e-06  -3.61873e-02

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[12]>>hPW4" );
hPW4->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=34.7666 FROM MIGRAD    STATUS=CONVERGED      52 CALLS          53 TOTAL
#                      EDM=4.84192e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.92006e+03   2.15785e+01   5.09274e-02  -5.55059e-05
#    2  Mean         8.79920e+02   9.22647e-02   4.19579e-04   1.59160e-03
#    3  Sigma        1.00684e+01   6.67606e-02   5.16170e-06  -3.72219e-01
