# %%
TFile * f = new TFile( "ntuple_d117_good.root" )
# Out:
# (TFile *) 0x6fe0980
# TClass::Init:0: RuntimeWarning: no dictionary for class StPicoEvent is available
# TClass::Init:0: RuntimeWarning: no dictionary for class StThreeVector<double> is available

# %%
vpdPico->Draw( "bbqTdcEast - bbqTdcEast[11]: Iteration$ >> hEast( 16, 0, 16, 500, -250, 250 )", " bbqTdcEast > 180 && Iteration$ != 11 && Iteration$ %4 != 0", "colz" );
hEast->Fit("pol0");
c1->Draw();
c1->SetLogz(1);
gStyle->SetOptFit( 111 )
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =  5.04622e+08
# NDf                       =         4449
# p0                        =     -4.34232   +/-   0.751173

# %%
vpdPico->Draw( "bbqTdcWest - bbqTdcEast[11]: Iteration$ >> hWest( 16, 0, 16, 500, -250, 250 )", "bbqTdcEast[11] > 180 && bbqTdcWest > 180 && Iteration$ != 11 && Iteration$ %4 != 0", "colz" );
hWest->Fit("pol0");
c1->Draw();

c1->SetLogz(1);
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =  6.06427e+08
# NDf                       =         4476
# p0                        =       32.435   +/-   0.892629

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcEast[0]>>hPE1" );
hPE1->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=133.944 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
#                      EDM=3.10865e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     8.85230e+02   7.01154e+00   3.21627e-02   1.23367e-04
#    2  Mean         8.09931e+02   7.06702e-02   3.99983e-04   4.61940e-03
#    3  Sigma        1.09972e+01   5.14247e-02   7.12310e-06   2.07780e-01

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcEast[4]>>hPE2" );
hPE2->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=146.614 FROM MIGRAD    STATUS=CONVERGED      52 CALLS          53 TOTAL
#                      EDM=2.63177e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.43303e+02   5.80773e+00   2.82354e-02  -6.64358e-05
#    2  Mean         1.03067e+03   8.51311e-02   4.98445e-04   3.14645e-03
#    3  Sigma        1.30922e+01   5.88497e-02   7.18525e-06  -5.77422e-01

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcEast[8]>>hPE3" );
hPE3->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=87.7304 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=3.87172e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.60080e+03   1.23858e+01   4.70938e-02  -5.96632e-07
#    2  Mean         9.90229e+02   7.86379e-02   4.72178e-04  -4.76143e-05
#    3  Sigma        1.21847e+01   5.31343e-02   5.46216e-06   1.00253e-03

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcEast[12]>>hPE4" );
hPE4->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=169.209 FROM MIGRAD    STATUS=CONVERGED      62 CALLS          63 TOTAL
#                      EDM=1.19515e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     8.38542e+02   6.53514e+00   3.42240e-02   1.19005e-08
#    2  Mean         7.67674e+02   7.56469e-02   4.73565e-04   1.91429e-04
#    3  Sigma        1.15919e+01   5.15253e-02   7.60820e-06   2.31737e-03

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[0]>>hPW1" );
hPW1->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=703.789 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=3.38746e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.71841e+02   2.93499e+00   3.12243e-02   1.04398e-04
#    2  Mean         1.11668e+03   1.80268e-01   2.16495e-03  -4.38137e-03
#    3  Sigma        2.56000e+01   1.16935e-01   1.51629e-05   1.06542e-01

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[4]>>hPW2" );
hPW2->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=299.865 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=1.24381e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.50824e+02   5.95250e+00   4.08498e-02   3.71600e-05
#    2  Mean         1.02058e+03   8.54035e-02   7.02321e-04   4.58480e-03
#    3  Sigma        1.28801e+01   6.00951e-02   1.03627e-05  -1.50894e-01

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[8]>>hPW3" );
hPW3->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=169.896 FROM MIGRAD    STATUS=CONVERGED      62 CALLS          63 TOTAL
#                      EDM=7.56867e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     6.95859e+02   5.41848e+00   2.84584e-02  -6.55053e-06
#    2  Mean         9.46499e+02   9.10050e-02   5.72572e-04  -1.92008e-04
#    3  Sigma        1.39713e+01   6.20660e-02   7.63765e-06   1.28160e-03

# %%
gStyle->SetOptFit(111);
vpdPico->Draw( "bbqTdcWest[12]>>hPW4" );
hPW4->Fit( "gaus" );
c1->Draw();
# Out:
#  FCN=104.029 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
#                      EDM=1.59189e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.06035e+03   8.32469e+00   3.39500e-02  -1.10925e-06
#    2  Mean         8.77296e+02   5.90511e-02   4.18327e-04  -2.66543e-04
#    3  Sigma        9.19091e+00   4.18522e-02   6.13404e-06  -5.29951e-03
